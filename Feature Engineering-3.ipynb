# %%
Q1. What is Min-Max scaling, and how is it used in data preprocessing? Provide an example to illustrate its
    application.

# %%
Ans : Min-Maz scaling :  Min-max normalization is one of the most common ways to normalize data. For every feature,
                         the minimum value of that feature gets transformed into a 0, the maximum value gets 
                         transformed into a 1, and every other value gets transformed into a decimal between 0 
                         and 1.
            
            For example, if the minimum value of a feature was 20, and the maximum value was 40, then 30 would be
            transformed to about 0.5 since it is halfway between 20 and 40. The formula is as follows:
                
                min_max = (x_i - x_min)/(x_max - x_min)
                
             Min-Max Normalization preserves the relationships among the original data values. It will encounter
            an out-of-bounds error if a future input case for normalization falls outside the first data range for
            A.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
import pandas as pd

# %%
df = pd.DataFrame([10,34,20,40,55,23,67,50,45,56,45],columns=['data'])

# %%
df
# Out:
#     data
# 0     10
# 1     34
# 2     20
# 3     40
# 4     55
# 5     23
# 6     67
# 7     50
# 8     45
# 9     56
# 10    45

# %%
min_max = MinMaxScaler()

# %%
df1 = pd.DataFrame(min_max.fit_transform(df),columns=['min_max'])

# %%
df1
# Out:
#      min_max
# 0   0.000000
# 1   0.421053
# 2   0.175439
# 3   0.526316
# 4   0.789474
# 5   0.228070
# 6   1.000000
# 7   0.701754
# 8   0.614035
# 9   0.807018
# 10  0.614035

# %%
pd.concat([df,df1],axis=1)
# Out:
#     data   min_max
# 0     10  0.000000
# 1     34  0.421053
# 2     20  0.175439
# 3     40  0.526316
# 4     55  0.789474
# 5     23  0.228070
# 6     67  1.000000
# 7     50  0.701754
# 8     45  0.614035
# 9     56  0.807018
# 10    45  0.614035

# %%
Q2. What is the Unit Vector technique in feature scaling, and how does it differ from Min-Max scaling?
    Provide an example to illustrate its application.

# %%
Ans : Unit Vector Scaling technique is done considering the whole feature vector to be of unit length,
      Unit vector scaling means dividing each component by the Euclidean length of the vector (L2 Norm),
      Unit Vector technique produces values of range [0,1].
     
     When dealing with features with hard boundaries, this is quite useful 
    ex. when dealing with image data, the colors can range from only 0 to 255.
    
    Min-Max scaling convert the data points ib between [0,1] but unit vector technique in a unit vector to each 
    Data.

# %%
import seaborn as sns

# %%
df= sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.preprocessing import normalize 
import pandas as pd

# %%
df1 =normalize(df[['sepal_width',	'petal_length',	'petal_width']])

# %%
df = pd.concat([pd.DataFrame(df1,columns=['sepal_width',	'petal_length',	'petal_width']),df],axis=1)

# %%
df
# Out:
#      sepal_width  petal_length  petal_width  sepal_length  sepal_width  \
# 0       0.927173      0.370869     0.052981           5.1          3.5
# 1       0.904534      0.422116     0.060302           4.9          3.0
# 2       0.924917      0.375748     0.057807           4.7          3.2
# 3       0.898645      0.434828     0.057977           4.6          3.1
# 4       0.930758      0.361961     0.051709           5.0          3.6
# ..           ...           ...          ...           ...          ...
# 145     0.466647      0.808855     0.357763           6.7          3.0
# 146     0.423425      0.846850     0.321803           6.3          2.5
# 147     0.474105      0.821781     0.316070           6.5          3.0
# 148     0.501248      0.796100     0.339080           6.2          3.4
# 149     0.485071      0.824621     0.291043           5.9          3.0
#
#      petal_length  petal_width    species
# 0             1.4          0.2     setosa
# ...

# %%
Q3. What is PCA (Principle Component Analysis), and how is it used in dimensionality reduction? Provide an
    example to illustrate its application.

# %%
Ans : Principal Component Analysis is an unsupervised learning algorithm that is used for the dimensionality
      reduction in machine learning. It is a statistical process that converts the observations of correlated 
      features into a set of linearly uncorrelated features with the help of orthogonal transformation.
        
        PCA generally tries to find the lower-dimensional surface to project the high-dimensional data.
        PCA works by considering the variance of each attribute because the high attribute shows the
        good split between the classes, and hence it reduces the dimensionality. Some real-world applications
        of PCA are image processing, movie recommendation system, optimizing the power allocation in various 
        communication channels.
        
        Application
        1. PCA is mainly used as the dimensionality reduction technique in various AI applications such as computer
        vision, image compression, etc.
        2.It can also be used for finding hidden patterns if data has high dimensions. Some fields where PCA is
          used are Finance, data mining, Psychology, etc

# %%
Q4. What is the relationship between PCA and Feature Extraction, and how can PCA be used for Feature
    Extraction? Provide an example to illustrate this concept.

# %%
Ans : PCA is one of the commonly used techniques for feature extraction. It works by finding the principal 
      components of the data, which are linear combinations of the original features. These principal components
      are ordered in terms of their ability to explain the variance in the data. The first principal component
        captures the most significant variation, the second component captures the second most significant
        variation, and so on.
        
        In the context of feature extraction, PCA can be used to transform a high-dimensional dataset into a
        lower-dimensional space by projecting the data onto a subset of principal components. The new set of 
        features can then be used for various purposes, such as visualization, classification, clustering, or 
        regression. By capturing the most important patterns in the data, PCA can help simplify the subsequent 
        analysis and improve the efficiency and effectiveness of machine learning algorithms.
        
        1.PCA in machine learning is used to visualize multidimensional data.
        2.In healthcare data to explore the factors that are assumed to be very important 
          in increasing the risk of any chronic disease.
        3.PCA helps to resize an image.
        4.PCA is used to analyze stock data and forecasting data.
        5.You can also use Principal Component Analysis to analyze patterns when you are dealing with 
           high-dimensional data sets.

# %%
Q5. You are working on a project to build a recommendation system for a food delivery service. The dataset
    contains features such as price, rating, and delivery time. Explain how you would use Min-Max scaling to
    preprocess the data.

# %%
Ans : Min-Max scaling is a commonly used technique for data preprocessing, especially when dealing with 
      numerical features that have different ranges or units. In the context of building a recommendation 
      system for a food delivery service, Min-Max scaling can be applied to features such as price, rating, 
      and delivery time to ensure that they are on a similar scale and have a consistent range.
      
    Here is the  step-by-step explanation of how Min-Max scaling can be used to preprocess the data:
        
        1.Understand the data: Begin by understanding the range and distribution of each feature in the dataset.
        2.Identify the minimum and maximum values: In given features price , rating and delivery time we will
          identify the minimum and maximum valuse for min-max scaling.
        3.Apply the Min-Max scaling formula: apply the formula on each data of every features, to scale the data in 
          range of 0 to 1.
             formula = (x_i - x_max)/(x_max - x_min) 
        4.Interpret the scaled values: After applying Min-Max scaling, the values for each feature will be
          between 0 and 1. A value of 0 represents the minimum value of the feature, while a value of 1 
          represents the maximum value. Values in between represent the relative position of the data point 
          within the range.
        5.Use the scaled data for recommendation: Once the data has been scaled using Min-Max scaling, it can 
          be used as input for the recommendation system.
            
    By applying Min-Max scaling to features such as price, rating, and delivery time, the recommendation system 
    can effectively process and compare the data to generate accurate recommendations based on user preferences.

# %%
Q6. You are working on a project to build a model to predict stock prices. The dataset contains many
    features, such as company financial data and market trends. Explain how you would use PCA to reduce the
    dimensionality of the dataset.

# %%
Ans : PCA can be applied to reduce the dimensionality of the dataset that includes features like company 
      financial data and market trends.
    
    1.Standardize the data: Start by standardizing the dataset to ensure that all features have a mean of 0 
      and a standard deviation of 1. This step is important as PCA is sensitive to the scale of the features.
    
    2.Calculate the covariance matrix: Compute the covariance matrix of the standardized dataset. 
      The covariance matrix captures the relationships between the different features and helps identify the
      directions of maximum variance.
    3.Compute the eigenvectors and eigenvalues
    4.Select the desired number of principal components:
    5.Project the data onto the new feature space
    6.Interpret the reduced dataset
    
    By using PCA to reduce the dimensionality of the dataset, you can eliminate redundant or less informative 
    features, focus on the most significant components, and potentially improve the performance of the stock
    price prediction model.

# %%
Q7. For a dataset containing the following values: [1, 5, 10, 15, 20], perform Min-Max scaling to transform the
    values to a range of -1 to 1.

# %%
# Ans : Given Data 
data = [1, 5, 10, 15, 20]

# %%
x_min= min(data)

# %%
x_max = max(data)

# %%
tran_value = []
for i in data:
    trans = (i-x_min)/(x_max-x_min)
    tran_value.append(trans)

# %%
tran_value
# Out:
# [0.0, 0.21052631578947367, 0.47368421052631576, 0.7368421052631579, 1.0]

# %%
Q8. For a dataset containing the following features: [height, weight, age, gender, blood pressure], perform
    Feature Extraction using PCA. How many principal components would you choose to retain, and why?

# %%
Ans : To perform feature extraction using PCA for the given dataset with features
      [height, weight, age, gender, blood pressure], we will follow the steps outlined in the previous answer:
        
        1.Standardize the data: We begin by standardizing the dataset to ensure that all features have a mean
           of 0 and a standard deviation of 1. This step is crucial to ensure that the PCA algorithm is not 
           biased towards features with larger scales.
        2.Calculate the covariance matrix: Compute the covariance matrix of the standardized dataset. 
            The covariance matrix captures the relationships between the different features and helps identify 
            the directions of maximum variance.
        3.Compute the eigenvectors and eigenvalues: Perform an eigendecomposition on the covariance matrix to 
           obtain its eigenvectors and eigenvalues. The eigenvectors represent the principal components, which
            are the new orthogonal axes that capture the maximum variance in the data. The eigenvalues indicate
            the amount of variance explained by each principal component.
        4.Select the desired number of principal components: Analyze the eigenvalues and their corresponding
          explained variance to determine the number of principal components to retain. The total variance
          explained by the principal components can help in deciding the appropriate number of components to 
          keep. You can set a threshold (e.g., retaining components that explain 90% of the variance).
            
            To decide on the number of principal components to retain, we can plot the cumulative explained 
            variance versus the number of components and choose the number of components that capture a
            satisfactory amount of the total variance.
            
            Keep in mind that the "gender" feature is categorical, so it would need to be appropriately encoded
            (e.g., one-hot encoding) before applying PCA.

            Without having the actual data and the covariance matrix, it's challenging to provide a precise
            number of principal components to retain. However, the decision would be based on the cumulative
            explained variance plot and the desired trade-off between variance retention and dimensionality
            reduction.
